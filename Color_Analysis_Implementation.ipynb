# %% [markdown]
# # An example on image color analysis

# %%
from color_analysis import multiple_images, elbow_curve, color_clustering, ImageAnalizer

# %% [markdown]
# ### The image

# %%
path = "Imgs_done/pan.jpg"
Imagen = ImageAnalizer(path, False, False)
Imagen.img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=267x400 at 0x7F67A8DA0438>

# %% [markdown]
# ### RGB components

# %%
Imagen.rgb_histogram()

# %%
Imagen.rgb_composite()

# %% [markdown]
# ### Generating the color sample with kmeans

# %%
maxclusters = 10
clusters = elbow_curve(maxclusters, Imagen.pixel_values)

# %%
# parameters: the number of clusters, and the output folder
Imagen.color_palette(clusters, "ColorPalette_resizedWKnee")

# %% [markdown]
# ### Saving the color sample data

# %%
Imagen.clusters_info("ColorCluster_resizedWKnee_", maxclusters)
