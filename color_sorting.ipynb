# %% [markdown]
# # Sorting images by their principal colors

# %%
import pandas as pd
from PIL import Image
import math
import colorsys
import os

# %% [markdown]
# ## Load the datasets

# %%
df_col = pd.read_csv("ColorClusterRGB.csv")
df_per = pd.read_csv("ColorClusterPercentage.csv")

# %%
df_col.head(10)
# Out:
#            mallows           peach2             lamp              mos  \
# 0  (237, 222, 225)    (156, 39, 42)   (242, 194, 91)    (28, 73, 108)
# 1  (207, 127, 140)  (226, 157, 123)  (239, 238, 242)  (189, 191, 197)
# 2  (222, 164, 176)       (24, 8, 5)   (189, 129, 16)    (105, 66, 41)
# 3    (170, 63, 75)    (220, 70, 75)   (221, 169, 56)   (53, 140, 184)
# 4  (232, 190, 199)     (96, 85, 43)  (217, 215, 219)     (20, 22, 30)
# 5              NaN   (164, 115, 88)              NaN  (150, 127, 106)
# 6              NaN     (83, 27, 22)              NaN              NaN
# 7              NaN              NaN              NaN              NaN
# 8              NaN              NaN              NaN              NaN
# 9              NaN              NaN              NaN              NaN
#
#               pipe              coc            peach          flowers  \
# 0     (29, 21, 13)  (162, 147, 142)   (240, 101, 89)      (29, 20, 9)
# ...

# %%
df_per.head(10)
# Out:
#    mallows  peach2  lamp   mos  pipe   coc  peach  flowers    ic  raccoon  \
# 0     29.0    19.0  17.0  24.0  12.0  10.0   18.0     19.0  16.0     19.0
# 1     10.0     8.0  47.0   8.0  29.0  11.0   16.0     26.0  11.0     27.0
# 2     24.0    14.0   6.0  12.0  16.0  47.0   26.0      7.0  19.0     15.0
# 3      2.0    19.0  10.0  16.0   8.0   7.0   23.0     16.0  17.0     21.0
# 4     36.0     9.0  19.0  29.0  12.0  26.0   10.0     16.0  13.0     18.0
# 5      NaN    11.0   NaN  11.0  23.0   NaN    6.0     16.0  25.0      NaN
# 6      NaN    20.0   NaN   NaN   NaN   NaN    NaN      NaN   NaN      NaN
# 7      NaN     NaN   NaN   NaN   NaN   NaN    NaN      NaN   NaN      NaN
# 8      NaN     NaN   NaN   NaN   NaN   NaN    NaN      NaN   NaN      NaN
# 9      NaN     NaN   NaN   NaN   NaN   NaN    NaN      NaN   NaN      NaN
#
#                  ...                 eb3793fe21d9ea837eb5e1f619bda67b  \
# 0                ...                                              8.0
# ...

# %% [markdown]
# ## Extract the maximum value per column

# %%
first_max = []
imgs_name = []
for i in df_col.keys():
    imgs_name = imgs_name + [i]
    maxs = df_per[i].nlargest(1).keys()
    first_max = first_max + [df_col[i][maxs[0]]]

# %%
from ast import literal_eval as make_tuple

first_max = list(map(make_tuple, first_max))

# %% [markdown]
# ## Color strip image

# %%
def color_strip(size, values, name):
    '''
    Color Sampler
    
    - Description 
        Saves a stripe of RGB colors of desired length.
    
    - Parameters
        size: a list of width and height values
        values: the RGB values to plot
    
    '''
    
    if not os.path.isdir("color_strip"):
        os.makedirs("color_strip")
        
    sample = []
    width, height = size
    temp = Image.new('RGB', (width, height))
    new_img = Image.new('RGB', (width*len(values), height))
    x_offset = 0 
    
    for val in values:
        sample = [val] * ((width*height))
        temp.putdata(sample)
        new_img.paste(temp, (x_offset,0))
        x_offset = x_offset + width
    
    new_img.save("color_strip/"+ name + '.jpg')

# %% [markdown]
# ## Color sorting

# %% [markdown]
# ### RGB sorting

# %% [markdown]
# The most simple way of sorting. First, it sorts the first component (R: red), then the second (G: green) and finally the third (B: blue) of the principal color of the image.

# %%
RGB = list(zip(imgs_name, first_max))
sorted_RGB = sorted(RGB, key=lambda row: row[1])
sorted_RGB[0:10]
# Out:
# [('edc9df272ba8f3408a6e0b8adca77aab', (2, 2, 2)),
#  ('bjork2', (3, 3, 4)),
#  ('umbrella', (6, 8, 23)),
#  ('lea', (6, 55, 50)),
#  ('matcha', (7, 8, 3)),
#  ('av', (8, 13, 8)),
#  ('lea2', (9, 22, 19)),
#  ('teal', (10, 107, 96)),
#  ('4cce5f10e307d2c1e501938389db9fa0', (11, 6, 13)),
#  ('5ed104747032281d9e8a49366c2f694b', (11, 14, 3))]

# %%
values_RGB = [x[1] for x in sorted_RGB]
color_strip([20,100], values_RGB, 'ColorStrip_RGB')

# %% [markdown]
# ### HSV sorting

# %% [markdown]
# The HSV color space represents the similarity between colors better than the RGB space. It uses hue, saturation and value as parameters.

# %%
def hsv(x): 
    return(colorsys.rgb_to_hsv(*x))

# %%
hsv_t = []
for i in first_max:
    hsv_t = hsv_t + [hsv(i)]

HSV = list(zip(imgs_name, first_max, hsv_t))
HSV[0:10]
# Out:
# [('mallows', (232, 190, 199), (0.9642857142857143, 0.1810344827586207, 232)),
#  ('peach2', (83, 27, 22), (0.013661202185792346, 0.7349397590361446, 83)),
#  ('lamp', (239, 238, 242), (0.7083333333333334, 0.01652892561983471, 242)),
#  ('mos', (20, 22, 30), (0.6333333333333333, 0.3333333333333333, 30)),
#  ('pipe', (218, 215, 212), (0.08333333333333333, 0.027522935779816515, 218)),
#  ('coc', (220, 223, 225), (0.5666666666666668, 0.022222222222222223, 225)),
#  ('peach', (178, 54, 52), (0.0026455026455026545, 0.7078651685393258, 178)),
#  ('flowers', (239, 159, 14), (0.1074074074074074, 0.9414225941422594, 239)),
#  ('ic', (191, 184, 155), (0.13425925925925927, 0.18848167539267016, 191)),
#  ('raccoon', (36, 34, 34), (0.0, 0.05555555555555555, 36))]

# %%
sorted_HSV = sorted(HSV, key=lambda row: row[2])
values_HSV = [x[1] for x in sorted_HSV]
color_strip([20,100], values_HSV, 'ColorStrip_HSV')

# %% [markdown]
# ### HLS sorting

# %% [markdown]
# HLS is similar to HSV, but instead the color space is organized by hue, saturation and lightness

# %%
def hls(x):
    return(colorsys.rgb_to_hls(*x))

# %%
hls_t = []
for i in first_max:
    hls_t = hls_t + [hls(i)]

HLS = list(zip(imgs_name, first_max, hls_t))
HLS[0:10]
# Out:
# [('mallows', (232, 190, 199), (0.9642857142857143, 211.0, -0.1)),
#  ('peach2', (83, 27, 22), (0.013661202185792346, 52.5, -0.5922330097087378)),
#  ('lamp', (239, 238, 242), (0.7083333333333334, 240.0, -0.008368200836820083)),
#  ('mos', (20, 22, 30), (0.6333333333333333, 25.0, -0.20833333333333334)),
#  ('pipe',
#   (218, 215, 212),
#   (0.08333333333333333, 215.0, -0.014018691588785047)),
#  ('coc', (220, 223, 225), (0.5666666666666668, 222.5, -0.011286681715575621)),
#  ('peach', (178, 54, 52), (0.0026455026455026545, 115.0, -0.5526315789473685)),
#  ('flowers', (239, 159, 14), (0.1074074074074074, 126.5, -0.896414342629482)),
#  ('ic', (191, 184, 155), (0.13425925925925927, 173.0, -0.10465116279069768)),
#  ('raccoon', (36, 34, 34), (0.0, 35.0, -0.029411764705882353))]

# %%
sorted_HLS = sorted(HLS, key=lambda row: row[2])
values_HLS = [x[1] for x in sorted_HLS]
color_strip([20,100], values_HLS, 'ColorStrip_HLS')

# %% [markdown]
# ### Luminosity sorting

# %% [markdown]
# Sorts by the percieved luminosity of the color

# %%
def lum (r,g,b):
    return math.sqrt( .241 * r + .691 * g + .068 * b )

# %%
lum_t = []
for i in first_max:
    lum_t = lum_t + [lum(*i)]

LUM = list(zip(imgs_name, first_max, lum_t))
LUM[0:10]
# Out:
# [('mallows', (232, 190, 199), 14.168062676315348),
#  ('peach2', (83, 27, 22), 6.336876202041507),
#  ('lamp', (239, 238, 242), 15.443866096285605),
#  ('mos', (20, 22, 30), 4.697020332082883),
#  ('pipe', (218, 215, 212), 14.680565384207789),
#  ('coc', (220, 223, 225), 14.913517358423531),
#  ('peach', (178, 54, 52), 9.151393336536245),
#  ('flowers', (239, 159, 14), 12.977673135042352),
#  ('ic', (191, 184, 155), 13.554150655795441),
#  ('raccoon', (36, 34, 34), 5.8721376005676165)]

# %%
sorted_LUM = sorted(LUM, key=lambda row: row[2])
values_LUM = [x[1] for x in sorted_LUM]
color_strip([20,100], values_LUM, 'ColorStrip_lum')

# %% [markdown]
# ### Step sorting

# %% [markdown]
# Based on the HSV color space, but also sorts by luminosity, generating a number of color segments. The ideal number of segments varies from dataset to dataset. To add continuity to the segments, the second step method inverts the luminosity every two segments.

# %%
def step (r,g,b, repetitions=1):
    
    lum = math.sqrt( .241 * r + .691 * g + .068 * b )
    h, s, v = colorsys.rgb_to_hsv(r,g,b)
    
    h2 = int(h * repetitions)
    lum2 = int(lum * repetitions)
    v2 = int(v * repetitions)
    
    return (h2, lum, v2)

# %%
for j in range(0,20):
    step_t = []
    number_steps = j
    for i in first_max:
        step_t = step_t + [step(*i, number_steps)]

    STEP = list(zip(imgs_name, first_max, step_t))
    sorted_STEP = sorted(STEP, key=lambda row: row[2])
    values_STEP = [x[1] for x in sorted_STEP]
    color_strip([20,100], values_STEP, 'ColorStrip_STEP' + str(number_steps))

# %%
sorted_STEP = sorted(STEP, key=lambda row: row[2])
values_STEP = [x[1] for x in sorted_STEP]
color_strip([20,100], values_STEP, 'ColorStrip_STEP' + str(number_steps))

# %%
def step_lum (r,g,b, repetitions=1):
    
    lum = math.sqrt( .241 * r + .691 * g + .068 * b )
    h, s, v = colorsys.rgb_to_hsv(r,g,b)
    
    h2 = int(h * repetitions)
    lum2 = int(lum * repetitions)
    v2 = int(v * repetitions)
    
    if h2 % 2 == 1:
        v2 = repetitions - v2
        lum = repetitions - lum
        
    return (h2, lum, v2)

# %%
for j in range(0,20):
    steplum_t = []
    number_steps = j
    for i in first_max:
        steplum_t = steplum_t + [step_lum(*i, number_steps)]

    STEP_LUM = list(zip(imgs_name, first_max, steplum_t))
    sorted_STEP_LUM = sorted(STEP_LUM, key=lambda row: row[2])
    values_STEP_LUM = [x[1] for x in sorted_STEP_LUM]
    color_strip([20,100], values_STEP_LUM, 'ColorStrip_STEP_lum' + str(number_steps))

# %% [markdown]
# ## Plot the sorted images

# %%
steplum_t = []
number_steps = 5
for i in first_max:
    steplum_t = steplum_t + [step_lum(*i, number_steps)]

STEP_LUM = list(zip(imgs_name, first_max, steplum_t))
sorted_STEP_LUM = sorted(STEP_LUM, key=lambda row: row[2])
values_STEP_LUM = [x[1] for x in sorted_STEP_LUM]

color_strip([20,100], values_STEP_LUM, 'ColorStrip_STEP_lum' + str(number_steps))

# %%
best_sort = sorted_STEP_LUM
best_sort[0:10]
# Out:
# [('edc9df272ba8f3408a6e0b8adca77aab', (2, 2, 2), (0, 1.4142135623730951, 10)),
#  ('eb3793fe21d9ea837eb5e1f619bda67b',
#   (21, 10, 7),
#   (0, 3.528030612112089, 105)),
#  ('41bad729417d7af185e7489178310dfa',
#   (17, 14, 10),
#   (0, 3.801447092884498, 85)),
#  ('agra', (43, 8, 7), (0, 4.045614909998231, 215)),
#  ('mandm', (51, 24, 24), (0, 5.523314222457382, 255)),
#  ('f90d03c14377bb18e26081ee8eecd20d',
#   (38, 31, 24),
#   (0, 5.675473548524387, 190)),
#  ('raccoon', (36, 34, 34), (0, 5.8721376005676165, 180)),
#  ('peach2', (83, 27, 22), (0, 6.336876202041507, 415)),
#  ('plumas', (129, 38, 36), (0, 7.7327226770394395, 645)),
#  ('erizo', (73, 67, 63), (0, 8.256754810456709, 365))]

# %%
def bla(path):
    img = Image.open(path)
    size = img.size
    return(img, size)

# %%
A, s = bla("Imgs_done/mallows.jpg")

# %%
s
# Out:
# (480, 720)

# %%
list((map(lambda x: x/2, s)))
# Out:
# [240.0, 360.0]
